# %%
import numpy as np
import time
import pandas as pd
from datetime import datetime
from datetime import timedelta
from datetime import date

import re
import json

from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait




from bs4 import BeautifulSoup
from selenium import webdriver 
from selenium.webdriver.support import expected_conditions as EC

import sqlalchemy
import pandas as pd
from sqlalchemy import create_engine, text
import psycopg2

# %%
connection = {
    'host': 'rc1b-7ng6ih3jte3824x8.mdb.yandexcloud.net',
    'port': 6432,
    'database': 'demo',
    'schema': 'lesson_6' ,
    'user': 'root',
    'password': 'password!!!', 
}
url = ('postgresql://{user}:{password}@{host}:{port}/{database}'
           .format(**connection))

engine = create_engine(url)

# %%
driver = webdriver.Chrome()

link= 'https://turserial.ru/meksikanskie-serialy/'
driver.get(link)
print(link)
wait = WebDriverWait(driver, 30)
page = driver.page_source
soup = BeautifulSoup(page, 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 driver = webdriver.Chrome()
#       3 link= 'https://turserial.ru/meksikanskie-serialy/'
# ----> 4 driver.get(link)
#       5 print(link)
#       6 wait = WebDriverWait(driver, 30)
#
# File C:\Anaconda\Lib\site-packages\selenium\webdriver\remote\webdriver.py:452, in WebDriver.get(self, url)
#     439 def get(self, url: str) -> None:
#     440     """Navigate the browser to the specified URL.
#     441
#     442     The method does not return until the page is fully loaded (i.e. the
#    (...)
#     450         `driver.get("https://example.com")`
#     451     """
# --> 452     self.execute(Command.GET, {"url": url})
#
# File C:\Anaconda\Lib\site-packages\selenium\webdriver\remote\webdriver.py:429, in WebDriver.execute(self, driver_command, params)
#     426     elif "sessionId" not in params:
#     427         params["sessionId"] = self.session_id
# --> 429 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     431 if response:
#     432     self.error_handler.check_response(response)
#
# File C:\Anaconda\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:406, in RemoteConnection.execute(self, command, params)
#     404 trimmed = self._trim_large_entries(params)
#     405 LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> 406 return self._request(command_info[0], url, body=data)
#
# File C:\Anaconda\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:430, in RemoteConnection._request(self, method, url, body)
#     427     body = None
#     429 if self._client_config.keep_alive:
# --> 430     response = self._conn.request(method, url, body=body, headers=headers, timeout=self._client_config.timeout)
#     431     statuscode = response.status
#     432 else:
#
# File C:\Anaconda\Lib\site-packages\urllib3\_request_methods.py:143, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     135     return self.request_encode_url(
#     136         method,
#     137         url,
#    (...)
#     140         **urlopen_kw,
#     141     )
#     142 else:
# --> 143     return self.request_encode_body(
#     144         method, url, fields=fields, headers=headers, **urlopen_kw
#     145     )
#
# File C:\Anaconda\Lib\site-packages\urllib3\_request_methods.py:278, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     274     extra_kw["headers"].setdefault("Content-Type", content_type)
#     276 extra_kw.update(urlopen_kw)
# --> 278 return self.urlopen(method, url, **extra_kw)
#
# File C:\Anaconda\Lib\site-packages\urllib3\poolmanager.py:457, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     455     response = conn.urlopen(method, url, **kw)
#     456 else:
# --> 457     response = conn.urlopen(method, u.request_uri, **kw)
#     459 redirect_location = redirect and response.get_redirect_location()
#     460 if not redirect_location:
#
# File C:\Anaconda\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File C:\Anaconda\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File C:\Anaconda\Lib\site-packages\urllib3\connection.py:571, in HTTPConnection.getresponse(self)
#     568 _shutdown = getattr(self.sock, "shutdown", None)
#     570 # Get the response from http.client.HTTPConnection
# --> 571 httplib_response = super().getresponse()
#     573 try:
#     574     assert_header_parsing(httplib_response.msg)
#
# File C:\Anaconda\Lib\http\client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File C:\Anaconda\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File C:\Anaconda\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File C:\Anaconda\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
navigation_div = soup.find('div', class_='navigation fx-row fx-start')

# %%
numbers = []

for element in navigation_div.find_all(['span', 'a']):
    text = element.get_text(strip=True)
    if text.isdigit():
        numbers.append(int(text))

# %%
for num in numbers:
    print(f"https://turserial.ru/meksikanskie-serialy/page/{num}/")

# %%
def extract_series_data(soup):
    """
    Извлекает информацию о сериале из HTML-разметки
    
    Args:
        html_content: HTML-строка с разметкой сериала
        
    Returns:
        Словарь с данными: title, production_year, views
    """
   
    result = {
        'title': None,
        'production_year': None,
        'views': None
    }
    
    title_element = soup.find('a', class_='short-title')
    if title_element:
        result['title'] = title_element.get_text(strip=True)
    
    
    for li in soup.find_all('li'):
        if 'Год выхода:' in li.get_text():
            year_match = re.search(r'\b(19|20)\d{2}\b', li.get_text())
            if year_match:
                result['production_year'] = year_match.group(0)
            break

    views_element = soup.find('div', class_='short-meta-item fx-1')
    if views_element:
        views_text = views_element.get_text(strip=True)
        views_match = re.search(r'\d+', views_text)
        if views_match:
            result['views'] = int(views_match.group(0))
    
    return result

# %%
all_items = soup.find_all('div', class_='short-item')
all_items

# %%
all_data = []

for item in all_items:
    all_data.append (extract_series_data(item))
all_df =pd.DataFrame( all_data)
all_df

# %%
driver = webdriver.Chrome()
all_data = []
for num in numbers:
    link= f"https://turserial.ru/meksikanskie-serialy/page/{num}/"
    print(link)
    driver.get(link)
    wait = WebDriverWait(driver, 30)
    page = driver.page_source
    soup = BeautifulSoup(page, 'html.parser')
    all_items = soup.find_all('div', class_='short-item')

    for item in all_items:
        all_data.append (  extract_series_data(item) )
    time.sleep(5)
    
all_df =pd.DataFrame( all_data)

driver.close()
