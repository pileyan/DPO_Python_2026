# %% [markdown]
# # Разбираемся с нейронкой

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/ianpile/Documents/GitHub/DPO_Python_2026/lect16_VK bot'

# %%
with open('/Users/ianpile/Documents/GitHub/test_secrets.txt') as f:
    groq_key = f.read().split(' = ')[1]

# %% [markdown]
#     POST https://api.groq.com/openai/v1/chat/completions
#
#     curl https://api.groq.com/openai/v1/chat/completions -s \
#     -H "Content-Type: application/json" \
#     -H "Authorization: Bearer $GROQ_API_KEY" \
#     -d '{
#       "model": "llama-3.3-70b-versatile",
#       "messages": [{
#           "role": "user",
#           "content": "Explain the importance of fast language models"
#       }]
#     }'
#
#
# Модель такая: `llama-3.1-8b-instant`

# %%
import requests

# %%
a = 1
s = f'my string {a}'

s
# Out:
# 'my string 1'

# %%
text = 'Что такое асинзронное программирование'

# %%
# groq_key

# %%
import requests

def generate_answer(text):

    url = 'https://api.groq.com/openai/v1/chat/completions'

    headers = {
        'Authorization': f'Bearer {groq_key}',
        'Content-Type': 'application/json'
    }


    payload = {
        'model': 'llama-3.1-8b-instant',
        'messages': [{'role': 'user', 'content': text}],
        'max_tokens' : 500,
        'temperature' : 0.7
    }
    
    try:
        r = requests.post(url, headers = headers, json = payload, timeout = 10)
        data = r.json()
        
        return data['choices'][0]['message']['content']
    
    except: 
        
        print('Groq Error')
        return "Ошибка"

# %%
generate_answer('Когда дали первого нобеля по экономике')
# Out:
# 'Первый Нобелевский приз по экономике был присужден в 1969 году. Он был вручен американскому экономисту Полу Сэмюэлюсон, который получил премию за 1969 год за разработку новой экономической теории, в частности теории оптимального расширения. Однако Сэмюэльсон отказался от премии, сославшись на то, что не считает себя достойным лауреатом.\n\nПервый Нобелевский приз по экономике, который был действительно вручен, был присужден в 1970 году. Этому году были удостоены трех экономистов: Пол Сэмюэльсон, Эрнст Рёзенбергер и Лайнус Полинг не получил, а получили: Пол Сэмюэльсон, Эрнст Рёзенбергер и Гуннар Мирдаль.'

# %% [markdown]
# # Github
#
# На гите создали репозиторий (Private) , на нем файл main.py и файл requirements.txt, в котором выписаны все нужные для работы программы библиотеки
#
# `requests, uvicorn, fastapi`

# %% [markdown]
# # FastAPI
#
# [Мануал](https://habr.com/ru/articles/1005390/)
#
# Следуем ему

# %%
# !pip install "fastapi[all]"

# %%
from fastapi import FastAPI

app = FastAPI()

@app.get("/")
def read_root():
    return {"message": "Привет, Хабр!"}

# %% [markdown]
# # VK - создаем сообщество
#
#
# Делаем его закрытым
#
#
#     Сообщество -> Управление -> Дополнительно -> Работа с API -> CallbackAPI
#
# Типы событий - входящее/исходящее сообщение
#
#
# # В Render
#
# 1) Делаем Web Service
# 2) Линкуем туда github, который мы сделали
# 3) Команду для запуска пишем такую:
#
#             uvicorn main:app --host 0.0.0.0 --port 10000
#
# и жмем Deploy
#
#
# Если Deploy зеленый, значит все выкатилось успешно) Если нет, берем ошибку - кидаем в GPT
#
# Если все ок, должен получиться "сайт" примерно такого вида:
#         https://new-bot-repo.onrender.com
#
#
# Если за время, пока вы ковырялись, изменился confirmation (в ВК), вы его переставляете в списке Environment-переменных на Render
#
# # Отправка сообщений
#
# Для этого нужен специальный VK_TOKEN (от имени кого я тут отправляю сообщения)
#
#       https://vk.com/<название_твоей_группы>?act=api
#
# Идем в блок "Ключи доступа" и создаем ключ доступа :)
#
# Сгенерированный ключ доступа вставляем в Environment-переменные на Render

# %% [markdown]
# # Будем искать статьи на Arxiv

# %%
# !pip install arxiv
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6047 sha256=81f32517de1563497ec42cf97df223556962e178c40e6815d7bce99c3ed42ae9
#   Stored in directory: /Users/ianpile/Library/Caches/pip/wheels/3b/25/2a/105d6a15df6914f4d15047691c6c28f9052cc1173e40285d03
# Successfully built sgmllib3k
# ...

# %%
import arxiv

# Construct a client
client = arxiv.Client()

# Search for the 10 most recent articles matching the keyword "electron"
search = arxiv.Search(
    query="all:electron",
    max_results=20,
    sort_by=arxiv.SortCriterion.SubmittedDate,
    sort_order=arxiv.SortOrder.Descending
)

results = client.results(search)

print("Found results:")
# Iterate over the results and print the title and date
# for result in results:
#     print(f"- {result.title} (Published: {result.published.date()})")
# Out:
# Found results:

# %%
import arxiv

def arxiv_search_results(query):
    # Construct a client
    client = arxiv.Client()

    search = arxiv.Search(
        query = query ,
        max_results=20,
        sort_by=arxiv.SortCriterion.SubmittedDate,
        sort_order=arxiv.SortOrder.Descending
    )

    results = client.results(search)
    res = random.choices([(element.title, element.entry_id) 
                          for element in results], k = 5)
    
    message = ''
    
    for i in range(len(res)):
        s = f'{i+1}. ' + res[i][0] + '.\n' + res[i][1] + '\n\n'
        message+=s
        
    return message

# %%
arxiv_search_results('Witten black holes')
# Out:
# '1. Non-Minimally Coupled Scalar Field, Area Quantization and Black Hole Entropy.\nhttp://arxiv.org/abs/2603.25292v1\n\n2. Interior of Schwarzschild in semiclassical gravity.\nhttp://arxiv.org/abs/2603.25683v1\n\n3. Non parametric constraints of gravitational-electromagnetic luminosity distance ratio.\nhttp://arxiv.org/abs/2603.25305v1\n\n4. Measurement of dijet angular distributions and search for beyond the standard model physics in proton-proton collisions at $\\sqrt{s}$ = 13 TeV.\nhttp://arxiv.org/abs/2603.25458v1\n\n5. $θ$ Angle and Axial Anomaly in Holographic QCD.\nhttp://arxiv.org/abs/2603.25729v1\n\n'

# %%
st = 'Arxiv: Cosmological Parameters, Dark Matter, Dark Energy, Large Scale Structure, Inflationary Theory.'

# %%
if st.startswith('Arxiv: ') is True:
    st[7:]
else: 
    отвечай сам
# Out:
# True

# %%
st[7:]
# Out:
# 'Cosmological Parameters, Dark Matter, Dark Energy, Large Scale Structure, Inflationary Theory.'

# %%
import random

# %%
lst = [(element.title, element.entry_id) for element in results]

# %%
# lst

# %%
res = random.choices(lst, k = 5)

# %%
res
# Out:
# [('Anomalous thermoelectric Hall response of interacting 2D Dirac fermions',
#   'http://arxiv.org/abs/2603.25705v1'),
#  ('Growth and Kerr magnetometry of Mn2Au on a gold-capped Nb(001) substrate',
#   'http://arxiv.org/abs/2603.25618v1'),
#  ('Worldwide Reactor Neutrino Propagation to Underground Labs: Matter Effects and Flux Predictions',
#   'http://arxiv.org/abs/2603.25655v1'),
#  ('Tensor network methods for bound electron-hole complexes beyond strong and weak confinement in nanoplatelets',
#   'http://arxiv.org/abs/2603.25439v1'),
#  ('Many-body Josephson diode effect in superconducting quantum interferometers',
#   'http://arxiv.org/abs/2603.25558v1')]

# %% [markdown]
# 1. Anomalous thermoelectric Hall response of interacting 2D Dirac fermions. \n
# http://arxiv.org/abs/2603.25705v1 \n\n
#
# 2. Growth and Kerr magnetometry of Mn2Au on a gold-capped Nb(001) substrate. \n
# http://arxiv.org/abs/2603.25618v1 \n\n

# %%
message = ''

for i in range(len(res)):
    s = f'{i+1}. ' + res[i][0] + '.\n' + res[i][1] + '\n\n'
    message+=s

# %%
print(message)
# Out:
# 1. Anomalous thermoelectric Hall response of interacting 2D Dirac fermions.
# http://arxiv.org/abs/2603.25705v1
#
# 2. Growth and Kerr magnetometry of Mn2Au on a gold-capped Nb(001) substrate.
# http://arxiv.org/abs/2603.25618v1
#
# 3. Worldwide Reactor Neutrino Propagation to Underground Labs: Matter Effects and Flux Predictions.
# http://arxiv.org/abs/2603.25655v1
#
# 4. Tensor network methods for bound electron-hole complexes beyond strong and weak confinement in nanoplatelets.
# http://arxiv.org/abs/2603.25439v1
#
# 5. Many-body Josephson diode effect in superconducting quantum interferometers.
# http://arxiv.org/abs/2603.25558v1

# %%
query = 'Bethe Ansatz'
max_results = 10

url = "http://export.arxiv.org/api/query"
params = {'search_query':query, 'start': 0, 'max_results': 10}
response = requests.get(url, params)
response.text
# Out:
# '<?xml version=\'1.0\' encoding=\'UTF-8\'?>\n<feed xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/" xmlns:arxiv="http://arxiv.org/schemas/atom" xmlns="http://www.w3.org/2005/Atom">\n  <id>https://arxiv.org/api/R5fCssCOSK2BoLhkpF/ZPcvJ1t0</id>\n  <title>arXiv Query: search_query=all:Bethe OR all:Ansatz&amp;id_list=&amp;start=0&amp;max_results=10</title>\n  <updated>2026-03-27T13:20:10Z</updated>\n  <link href="https://arxiv.org/api/query?search_query=all:Bethe+OR+all:Ansatz&amp;start=0&amp;max_results=10&amp;id_list=" type="application/atom+xml"/>\n  <opensearch:itemsPerPage>10</opensearch:itemsPerPage>\n  <opensearch:totalResults>16478</opensearch:totalResults>\n  <opensearch:startIndex>0</opensearch:startIndex>\n  <entry>\n    <id>http://arxiv.org/abs/1707.02584v2</id>\n    <title>The algebraic Bethe Ansatz and combinatorial trees</title>\n    <updated>2018-04-02T16:35:55Z</updated>\n    <link href="https://arxiv.org/abs/1707.02584v2" rel="alternate" type="text/html"/>\n    <
# ...

# %%
soup
