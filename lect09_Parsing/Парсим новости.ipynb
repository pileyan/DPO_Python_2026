# %%
import re
from bs4 import BeautifulSoup
import requests 
import pandas as pd

# %%
base_link = 'https://dzen.ru/news'

# %% [markdown]
# # пробуем 1

# %%
requests.get(base_link).text
# Out:
# '<body></body><script nonce=\'8f188b7dddf8f0fb50583e9ac29e0b85\'>var it = {"host":"https:\\u002F\\u002Fsso.dzen.ru\\u002Finstall?uuid=4e15cef9-88cc-461e-a1a1-4caac9e62410","retpath":"https:\\u002F\\u002Fdzen.ru\\u002Fnews?is_autologin_ya=true","dzen":"0"};(function() { var form = document.createElement(\'form\'); var element1 = document.createElement(\'input\'); var element2 = document.createElement(\'input\'); var element3 = document.createElement(\'input\'); element1.name = \'retpath\'; element1.type = \'hidden\'; element1.value = it.retpath; form.appendChild(element1); element2.name = \'container\'; element2.type = \'hidden\'; element2.value = \'1772125023.11745530.d4f-ZUJ_iVCHeN-k.1VkSGG2wueQutd7ud1l4vOAKWCnW0bR5HuT42ZbvdvXSY6F3f1KFjC3bq_vfkYfPfCp-OuwFegMs1G-Z6uEl0WZpOJcBbz_L_80vTQQS0AyyfKjKXkW89SlvCY0PvnZb_lU_9Q3oeZaLhWZbThDf1jC4MdfrnHUpmDI6xV_h6Xt4VH_GddF0_MDig-8Sip89zEs_zLfhIdH0UW89TiJ6FTkT5_ZSErMXBShby5IS-2BYGaWSkmjsHAd6IWaVYuwxN5y5GlOIl5Q0aDcSYu805uis3Y9UXHlvfdzrf-TfNNpZ993P
# ...

# %% [markdown]
# # Пробуем selenium

# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium import webdriver 
from selenium.webdriver.support import expected_conditions as EC

# %%
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select

# %%
driver = webdriver.Chrome()

# %%
driver.get(base_link)
# print(link)

# %%
# path = '//*[@id="search-input"]'
fullpath = '/html/body/div[3]/div[2]/header/header/div[2]/div/div/div/div/form/input'

# %%
fld = driver.find_element(By.XPATH, fullpath)

# %%
fld.click()

# %%
query = 'Telegram'

# %%
fld.send_keys(query)

# %%
find_button_path = '/html/body/div[3]/div[2]/header/header/div[2]/div/div/div/div[1]/form/div[2]/button/span'

# %%
find_button = driver.find_element(By.XPATH, find_button_path)

# %%
find_button.click()

# %%
to_click = '/html/body/div[3]/div[2]/div/div[2]/main/div/div[2]/div[1]/div/div[4]/div[1]/div[2]/div[1]/div[1]'

# %%
find_button = driver.find_element(By.XPATH, to_click)

# %%
find_button.click()

# %%
wait = WebDriverWait(driver, 10)
page = driver.page_source
soup = BeautifulSoup(page, 'html.parser')
