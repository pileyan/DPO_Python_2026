# %% [markdown]
# # Домашка на регулярные выражения :)

# %% [markdown]
# ## 1. Найти все email-адреса
#
# Из текста извлечь все корректные email-адреса (например: user.name+tag@example.co.uk).

# %%
import re
text = """
Write to us: support@mail.ru, user.name+tag@example.co.uk
Fake: test@@mail.com
"""


def find_emails(text):
    '''
    ваш код функции
    '''
    return email_list


# результат должен быть ['support@mail.ru', 'user.name+tag@example.co.uk']

# %% [markdown]
# ## 2. Проверить формат номера телефона
#
# Проверить строки на валидность телефонного номера в формате:
#
# +7 (xxx) xxx-xx-xx
#
#
# где x — цифры.

# %%
phones = [
    "+7 (999) 123-45-67",
    "+7 (12) 123-45-67",
    "+7 (888) 111-22-33"
]


# результат True, False, True

# %% [markdown]
# ## 3. Найти слова, НЕ заканчивающиеся на ing (Negative Lookahead)

# %%
text = "running jumping walk talk coding sleep"

# %% [markdown]
# # 4. Заменить все последовательности пробелов на один
#
# Текст может содержать табы, пробелы и переносы строк — заменить их одной пробелом.
#
# Здесь вам пригодится функция `re.sub`

# %%
text = 'fhgwjk.  fbnsw \t \r \n \n hgjkdlhfjkld'

# %% [markdown]
# # 5. Найти и валидировать IP-адреса
#
# Найти все IPv4-адреса в тексте (диапазон 0–255 в каждом октете).

# %%
text = "Servers: 192.168.0.1 bad 999.1.1.1 ok 8.8.8.8"

# Тут ответ должен быть ['192.168.0.1', '8.8.8.8']

# %% [markdown]
# # 6. Извлечь время
#
# Найти все временные метки в формате HH:MM (24-часовой формат), например 00:00–23:59.

# %%
text = "Meet at 09:30 or 23:59 or wrong 25:00"

# Должно вернуть 09:30 и 23:59. Если на входе будет 09:30:23, такое не берем)

# %% [markdown]
# # 7. Найти слова с удвоенными буквами
#
# Например: coffee, letter, balloon, но не code, python.

# %%
text = '''Hamlet, returned from his journey, comes upon a gravedigger singing as he digs.
Hamlet tries to find out who the grave is for and reflects on the skulls 
that are being dug up. A funeral procession approaches.
Hamlet soon realizes that the corpse is Ophelia’s. 
When Laertes in his grief leaps into her grave and curses Hamlet 
as the cause of Ophelia’s death, Hamlet comes forward. 
He and Laertes struggle, with Hamlet protesting his own love and grief for Ophelia.'''

# gravedigger, skulls, procession, approaches, soon, struggle

# %% [markdown]
# # 8. Про финансовую отчетность
#
# Владимиру потребовалось срочно запутать финансовую документацию. Но так, чтобы это было обратимо.
# Он не придумал ничего лучше, чем заменить каждое целое число (непрерывную последовательность цифр) на его куб. Помогите ему.
#
# Ввод:
#
#     Было закуплено 12 единиц техники
#     по 410.37 рублей.
#
# Вывод:
#
#     Было закуплено 1728 единиц техники
#     по 68921000.50653 рублей.
#
# Вам понадобится функция `re.sub` - вы как бы "подхватываете", что она нашла, возводите в куб функцией, а потом вставляете обратно)

# %%
# Пример - найди число и напиши его трижды 
def repeat(match):
    return match.group()*3


txt = 'gfhwjk 444 ghjkg 44 ghjk 2'

re.sub(r"\d+", repeat, txt)
# Out:
# 'gfhwjk 444444444 ghjkg 444444 ghjk 222'
