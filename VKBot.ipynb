# %%
# !pip3 install vk_api

# %%
import vk_api
from vk_api.longpoll import VkLongPoll, VkEventType

TOKEN = "VBdwiQIbzO6nO8wfpsJk"

vk_session = vk_api.VkApi(token=TOKEN)
vk = vk_session.get_api()
longpoll = VkLongPoll(vk_session)

print("Бот запущен...")

for event in longpoll.listen():
    if event.type == VkEventType.MESSAGE_NEW and event.to_me:
        user_id = event.user_id
        text = event.text.lower()

        if text == "привет":
            vk.messages.send(
                user_id=user_id,
                message="Привет! 👋",
                random_id=0
            )
        else:
            vk.messages.send(
                user_id=user_id,
                message="Я пока понимаю только слово 'привет'",
                random_id=0
            )
# Out:
# ---------------------------------------------------------------------------
# ApiError                                  Traceback (most recent call last)
# Cell In[2], line 8
#       6 vk_session = vk_api.VkApi(token=TOKEN)
#       7 vk = vk_session.get_api()
# ----> 8 longpoll = VkLongPoll(vk_session)
#      10 print("Бот запущен...")
#      12 for event in longpoll.listen():
#
# File /opt/miniconda3/lib/python3.11/site-packages/vk_api/longpoll.py:511, in VkLongPoll.__init__(self, vk, wait, mode, preload_messages, group_id)
#     507 self.pts = None
#     509 self.session = requests.Session()
# --> 511 self.update_longpoll_server()
#
# File /opt/miniconda3/lib/python3.11/site-packages/vk_api/longpoll.py:524, in VkLongPoll.update_longpoll_server(self, update_ts)
#     521 if self.group_id:
#     522     values['group_id'] = self.group_id
# --> 524 response = self.vk.method('messages.getLongPollServer', values)
#     525 self.key = response['key']
#     526 self.server = response['server']
#
# File /opt/miniconda3/lib/python3.11/site-packages/vk_api/vk_api.py:934, in VkApi.method(self, method, values, captcha_sid, captcha_key, raw, with_cookies)
#     931         if response is not None:
#     932             return response
# --> 934     raise error
#     936 return response if raw else response['response']
#
# ApiError: [5] User authorization failed: invalid access_token (4).
