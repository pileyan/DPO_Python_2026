# %% [markdown]
# # **Работа с файлами**

# %% [markdown]
# ## Типы файлов

# %% [markdown]
# + структурированные (табличные): csv, txt, xsl и т.д.
# + неструктурированные (текст): doc, txt и т.д.

# %% [markdown]
# ## Поиск пути к файлу

# %% [markdown]
# Функция `getcwd()` из модуля `os` возвращает нам путь к ваше рабочей папке. Так, например, в Windows по умолчанию Anaconda делает рабочей папкой для Jupyter папку пользователя в Users. Это можно изменить или глобально, прописав путь к вашей папке в свойствах, или локально в рамках сессии.

# %%
import os #библиотека которая занимается навигацией по компьютеру
os.getcwd()
# Out:
# '/Users/ianpile/Documents/GitHub/DPO_Python_2026/lect07_Files'

# %% [markdown]
# Метод `.listdir()` вернет нам список содержимого директории. Очень полезная функция - можно запустить цикл, если нужно обработать все файлы в папке.

# %%
os.listdir('/Users/ianpile/Rock Paper Scissors')
# Out:
# ['results_eps',
#  'Без названия.ipynb',
#  'snapshots',
#  'results_impurities.npz',
#  '.ipynb_checkpoints',
#  'plots',
#  'RPS.ipynb']

# %%
[i for i in os.listdir(os.getcwd()) if '.txt' in i]
# Out:
# ['task1.txt', 'example.txt']

# %%
os.walk??

# %%
list(os.walk('/Users/ianpile/Rock Paper Scissors'))
# Out:
# [('/Users/ianpile/Rock Paper Scissors',
#   ['results_eps', 'snapshots', '.ipynb_checkpoints', 'plots'],
#   ['Без названия.ipynb', 'results_impurities.npz', 'RPS.ipynb']),
#  ('/Users/ianpile/Rock Paper Scissors/results_eps',
#   ['plots'],
#   ['.DS_Store', 'data_eps_sweep.npz']),
#  ('/Users/ianpile/Rock Paper Scissors/results_eps/plots',
#   [],
#   ['q90_distance.png', 'defect_density.png', 'free_vortex_fraction.png']),
#  ('/Users/ianpile/Rock Paper Scissors/snapshots',
#   [],
#   ['snapshot_029000.png',
#    'snapshot_046000.png',
#    'snapshot_021500.png',
#    'snapshot_025000.png',
#    'snapshot_009500.png',
#    'snapshot_013000.png',
#    'snapshot_017500.png',
#    'snapshot_005500.png',
#    'snapshot_001000.png',
#    'snapshot_023500.png',
#    'snapshot_027000.png',
#    'snapshot_044000.png',
#    'snapshot_048000.png',
#    '.DS_Store',
#    'snapshot_007500.png',
#    'snapshot_003000.png',
#    'snapshot_019500.png',
#    'snapshot_011000.png',
#    'snapshot_015500.png',
#    'snapshot_015000.png',
#    'snapshot_011500.png',
#    'snapshot_003500.png',
#    'snapshot_007000.png',
#    'snapshot_019000.png',
#    'snapshot_027500.png',
#    'snapshot_023000.png',
#    'snapshot_040000.png',
#    'snapshot_001500.png',
#    'snapshot_005000.png',
#    'snapshot_009000.png',
#    'snapshot_017000.png',
#    'snapshot_013500.png',
#    'snapshot_042000.png',
#    'snapshot_025500.png',
#    'snapshot_021000.png',
#    'snapshot_029500.png',
#    'snapshot_012000.png',
#    'snapshot_016500.png',
#    'snapshot_008500.png',
#    'snapshot_004500.png',
#    'snapshot_000000.png',
#    'snapshot_036000.png',
#    'snapshot_028000.png',
#    'snapshot_020500.png',
#    'snapshot_024000.png',
#    'snapshot_018500.png',
#    'snapshot_006500.png',
#    'snapshot_002000.png',
#    'snapshot_010000.png',
#    'snapshot_014500.png',
#    'snapshot_038000.png',
#    'snapshot_022500.png',
#    'snapshot_026000.png',
#    'snapshot_034000.png',
#    'snapshot_030000.png',
#    'snapshot_026500.png',
#    'snapshot_022000.png',
#    'snapshot_014000.png',
#    'snapshot_010500.png',
#    'snapshot_018000.png',
#    'snapshot_002500.png',
#    'snapshot_006000.png',
#    'snapshot_024500.png',
#    'snapshot_020000.png',
#    'snapshot_032000.png',
#    'snapshot_028500.png',
#    'snapshot_000500.png',
#    'snapshot_004000.png',
#    'snapshot_016000.png',
#    'snapshot_012500.png',
#    'snapshot_008000.png']),
#  ('/Users/ianpile/Rock Paper Scissors/.ipynb_checkpoints',
#   [],
#   ['Без названия-checkpoint.ipynb', 'RPS-checkpoint.ipynb']),
#  ('/Users/ianpile/Rock Paper Scissors/plots',
#   [],
#   ['pair.png', 'n_d.png', 'xi.png'])]

# %% [markdown]
# ## Функция `open()`

# %% [markdown]
# ```python
# open('путь к файлу/название файла.расширение', mode = 'режим', encoding = 'кодировка')
# ```

# %% [markdown]
# **Расширения** с которыми работает функция `open()`:
# + .txt
# + .csv
# + .tsv
# + .html
# + .xlsx
# + .pdf
# + и д.р.

# %% [markdown]
# **Режими** работы с файлами, которые можно использовать с функцией `open()`:
# + `mode='r'` — _read,  **чтение**_. При отсутствии указанного файла выдается ошибка. Это режим по умолчанию
# + `mode='w'` — _write, **запись**_. При отсутствии указанного файла создается новый. При наличии файла содержимое перезаписывается
# + `mode='a'` — _append, **дозапись**_. При отсутствии указанного файла создается новый. При наличии файла новое содержимое дозаписывается после имеющегося
# + и д.р.

# %% [markdown]
# **Кодировки** файлов:
# + utf-8
# + latin-1
# + ISO-8859-5
# + dos
# + и д.р.

# %% [markdown]
# ## Открытие файла

# %% [markdown]
# Функция `open()` возвращает файловый объект
#
# Такой объект называется file handle или дескриптор файла

# %%
f = open('example.txt')
f
# Out:
# <_io.TextIOWrapper name='example.txt' mode='r' encoding='UTF-8'>

# %% [markdown]
# ```
# <<служебная информация> name='название файла.расширение' mode='режим' encoding='кодировка'>
# ```

# %% [markdown]
# ## Чтение файла

# %%
f = open('example.txt')
print(f.read())
f.close()
# Out:
# 1 one
# 2 two
# 3 three
# 4 four
# 5 five
# 6 six
# 7 seven
# 8 eight

# %% [markdown]
# После того как файл закрыт читать его уже нельзя

# %%
f.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 f.read()
#
# ValueError: I/O operation on closed file.

# %% [markdown]
# ## Оптимальная работа с файлами

# %% [markdown]
# Хорошим тоном при работе с файлами считается открывать их с помощью ключевого слова `with`. Преимущество этого способа в том, что файл закроется автоматически, когда закончатся вложенные операции.

# %% [markdown]
# ```python
# with open('путь к файлу/название.расширение', mode = 'режим', encoding = 'кодировка') as <псеводним файла>:
#   ...
# ```

# %% [markdown]
# ### Чтение файла

# %%
with open('example.txt', encoding = 'utf-8') as infile:
    read_data = infile.read()

# %%
print(read_data)
# Out:
# 1 one
# 2 two
# 3 three
# 4 four
# 5 five
# 6 six
# 7 seven
# 8 eight

# %% [markdown]
# ## Построчное чтение файла `mode = 'r'`

# %% [markdown]
# ### `.readline()`

# %%
f = open('example.txt', encoding = 'utf-8')
f.readline()
# Out:
# '1 one\n'

# %%
f.readline()
# Out:
# '2 two\n'

# %%
f.readline()
# Out:
# '3 three\n'

# %%
f.close()

# %% [markdown]
# ### через `for`

# %% [markdown]
# ```python
# with open('путь к файлу', mode = 'режим', encoding = 'кодировка') as <псеводним файла>:
#   for <строчка> in <псеводним файла>:
#     print(<строчка>)
# ```

# %%
s = '_one '
s.strip('_').strip()
# Out:
# 'one'

# %%
s = '_one_'
s.lstrip('_')
# Out:
# 'one_'

# %%
s = '_one_'
s.lstrip('_')

# %%
s = 'h kfijd fo'
s.replace(' ', '')
# Out:
# 'hkfijdfo'

# %%
with open('example.txt', encoding = 'utf-8') as infile:
    for l in infile:
        print(l.rstrip('\n'))
# Out:
# 1 one
# 2 two
# 3 three
# 4 four
# 5 five
# 6 six
# 7 seven
# 8 eight

# %% [markdown]
# ## Извлечение информации из файла

# %%
s = ' dbghs    ajk '
s.strip().split()
# Out:
# ['dbghs', 'ajk']

# %%
k = 0
ks = ''
with open('example.txt', mode = 'r', encoding = 'utf-8') as infile:
    for l in infile:
        s = l.strip().split()
        k+=int(s[0])
        ks+=s[1]+ ' '
print(k)
print(ks)
# Out:
# 36
# one two three four five six seven eight

# %% [markdown]
# ## Создание нового файла `mode = 'w'`

# %% [markdown]
# ```python
# with open('путь/название файла.расширение', mode = 'w', encoding = 'кодировка') as <псеводним файла>:
#   print(<то что хотим записать в файл>, file=<псеводним файла>)
# ```

# %%
with open('example_writing.txt', mode = 'w', encoding = 'utf-8') as outfile:
    print(k, file=outfile)

# %%
os.listdir('/Users/ianpile/Documents/GitHub/DPO_Python_2026/lect07_Files')
# Out:
# ['oblomov.txt',
#  'example_writing.txt',
#  'mbox.txt',
#  'task3.tsv',
#  'task2.csv',
#  'example.txt',
#  '.ipynb_checkpoints',
#  'files 2.ipynb',
#  'tryexpect.txt']

# %%
with open(os.getcwd()+'/example_writing.txt') as f:
    print(f.read())
# Out:
# one two three four five six seven eight

# %% [markdown]
# ## Дозаписываем в файла `mode = 'a'`

# %% [markdown]
# ```python
# with open('путь/название файла.расширение', mode = 'a', encoding = 'кодировка') as <псеводним файла>:
#   print(<то что хотим записать в файл>, file=<псеводним файла>)
# ```

# %%
with open('example_writing.txt', mode = 'a', encoding = 'utf-8') as outfile:
    print(ks, file=outfile)
#     append

# %%
with open('example_writing.txt', mode = 'w', encoding = 'utf-8') as outfile:
    print(ks, file=outfile)

# %% [markdown]
# ## Практика

# %% [markdown]
# ### Задание 1

# %% [markdown]
# Посчитайте частотность отправленных писем по часам **mbox.txt**

# %%
d = {}
with open('mbox.txt', mode = 'r', encoding = 'utf-8') as infile:
    for l in infile:
        if l.startswith('Date: ') and l.endswith(')\n'):
            l = l.split()[2][:2]
            if l in d:
                d[l]+=1
            else:
                d[l]=1
print(d)
# Out:
# {'09': 164, '18': 52, '16': 165, '15': 178, '14': 152, '11': 149, '10': 183, '07': 41, '06': 45, '04': 25, '19': 48, '17': 96, '13': 119, '12': 109, '08': 78, '05': 11, '03': 17, '02': 13, '20': 29, '22': 29, '21': 37, '00': 24, '23': 16, '01': 10}

# %% [markdown]
# ### Задание 2

# %% [markdown]
# Посчитайте частотность слов в текстовом файле **oblomov.txt** (без учета стоп-слов и знаков пунктуации)

# %% [markdown]
# Стоп-слова и символы пунктуации можно получить из модуля `nltk`

# %%
import nltk

from string import punctuation

punct = str(punctuation)
print(punct)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
punct.append('')

# %%
import re

k = 'kfdjlkgfjb;lfj4,]'
punct_re = '[%s]+'% re.escape(punct) #функция экранирования специальных символов
a = re.sub(punct_re, '', k)
a
# Out:
# 'kfdjlkgfjblfj4'

# %%
punct_re
# Out:
# '[!"\\#\\$%\\&\'\\(\\)\\*\\+,\\-\\./:;<=>\\?@\\[\\\\\\]\\^_`\\{\\|\\}\\~]+'

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')

stops = set(stopwords.words('russian'))
print(stops)
# Out:
# {'том', 'ни', 'разве', 'там', 'бы', 'всего', 'не', 'один', 'они', 'этом', 'ее', 'сейчас', 'еще', 'в', 'потому', 'без', 'них', 'или', 'все', 'много', 'хоть', 'чем', 'куда', 'опять', 'даже', 'хорошо', 'наконец', 'него', 'потом', 'здесь', 'тебя', 'были', 'какой', 'про', 'к', 'уже', 'почти', 'иногда', 'какая', 'кто', 'как', 'его', 'с', 'чего', 'конечно', 'ты', 'свою', 'был', 'во', 'же', 'из', 'эту', 'ли', 'их', 'этот', 'этой', 'моя', 'а', 'что', 'быть', 'будет', 'но', 'тоже', 'где', 'никогда', 'перед', 'мне', 'на', 'у', 'вас', 'до', 'другой', 'более', 'тем', 'больше', 'вы', 'себя', 'ним', 'мы', 'можно', 'над', 'ей', 'два', 'между', 'совсем', 'так', 'за', 'о', 'тогда', 'когда', 'об', 'надо', 'тот', 'такой', 'раз', 'всю', 'было', 'может', 'то', 'зачем', 'ней', 'чтобы', 'ведь', 'им', 'если', 'эти', 'меня', 'по', 'при', 'себе', 'он', 'нет', 'три', 'была', 'вдруг', 'нибудь', 'ну', 'под', 'я', 'того', 'будто', 'нее', 'всех', 'уж', 'лучше', 'этого', 'вам', 'ж', 'и', 'после', 'ничего', 'тут', 'для', 'через', 'мой', 'теперь', 'со', 'только', 'сам', 'да', 'ему', 'чтоб', 'вот', 'чуть', 'от', 'всегда', 'она', 'нас', 'нельзя', 'есть', 'впрочем'}
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/ianpile/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stops_norm = set([morph.parse(word)[0].normal_form for word in stops])
stops_norm
# Out:
# {'а',
#  'без',
#  'более',
#  'большой',
#  'будто',
#  'бы',
#  'быть',
#  'в',
#  'вдруг',
#  'ведь',
#  'весь',
#  'вот',
#  'впрочем',
#  'всегда',
#  'всё',
#  'вы',
#  'где',
#  'да',
#  'даже',
#  'два',
#  'для',
#  'до',
#  'другой',
#  'если',
#  'есть',
#  'ещё',
#  'ж',
#  'же',
#  'за',
#  'зачем',
#  'здесь',
#  'и',
#  'из',
#  'или',
#  'иногда',
#  'к',
#  'как',
#  'какой',
#  'когда',
#  'конечно',
#  'кто',
#  'куда',
#  'ли',
#  'между',
#  'много',
#  'можно',
#  'мой',
#  'мочь',
#  'мы',
#  'на',
#  'над',
#  'надо',
#  'наконец',
#  'не',
#  'нельзя',
#  'нет',
#  'ни',
#  'нибыть',
#  'никогда',
#  'ничего',
#  'но',
#  'ну',
#  'о',
#  'один',
#  'он',
#  'она',
#  'они',
#  'опять',
#  'от',
#  'перед',
#  'по',
#  'под',
#  'после',
#  'потом',
#  'потому',
#  'почти',
#  'при',
#  'про',
#  'раз',
#  'разве',
#  'с',
#  'сам',
#  'свой',
#  'себя',
#  'сейчас',
#  'совсем',
#  'так',
#  'такой',
#  'там',
#  'тем',
#  'теперь',
#  'то',
#  'тогда',
#  'тоже',
#  'только',
#  'тот',
#  'три',
#  'тут',
#  'ты',
#  'у',
#  'уж',
#  'уже',
#  'хороший',
#  'хорошо',
#  'хоть',
#  'чем',
#  'через',
#  'что',
#  'чтоб',
#  'чтобы',
#  'чуть',
#  'это',
#  'этот',
#  'я'}

# %% [markdown]
# Еще вам понадобится преобразовать слова в начальную форму, чтобы условное слово "корова" и "коровы" считалось как одно. Для этого вам понадобится модуль `pymorphy2`

# %%
# !pip uninstall pymorphy2
# Out:
# Found existing installation: pymorphy2 0.9.1
# Uninstalling pymorphy2-0.9.1:
#   Would remove:
#     /opt/miniconda3/bin/pymorphy
#     /opt/miniconda3/lib/python3.11/site-packages/pymorphy2-0.9.1.dist-info/*
#     /opt/miniconda3/lib/python3.11/site-packages/pymorphy2/*
# Proceed (Y/n)? ^C
# ERROR: Operation cancelled by user

# %%
import pymorphy3
morph = pymorphy3.MorphAnalyzer()

word = "коровы"
# word = "стали"
p = morph.parse(word)
print(p[0].normal_form)
# Out:
# корова

# %%
# p[0]
# Out:
# Parse(word='коровы', tag=OpencorporaTag('NOUN,anim,femn sing,gent'), normal_form='корова', score=0.5, methods_stack=((DictionaryAnalyzer(), 'коровы', 53, 1),))

# %%
word = "стали"

# %%
morph.parse(word)
# Out:
# [Parse(word='стали', tag=OpencorporaTag('VERB,perf,intr plur,past,indc'), normal_form='стать', score=0.975342, methods_stack=((DictionaryAnalyzer(), 'стали', 945, 4),)),
#  Parse(word='стали', tag=OpencorporaTag('NOUN,inan,femn sing,gent'), normal_form='сталь', score=0.010958, methods_stack=((DictionaryAnalyzer(), 'стали', 13, 1),)),
#  Parse(word='стали', tag=OpencorporaTag('NOUN,inan,femn plur,nomn'), normal_form='сталь', score=0.005479, methods_stack=((DictionaryAnalyzer(), 'стали', 13, 6),)),
#  Parse(word='стали', tag=OpencorporaTag('NOUN,inan,femn sing,datv'), normal_form='сталь', score=0.002739, methods_stack=((DictionaryAnalyzer(), 'стали', 13, 2),)),
#  Parse(word='стали', tag=OpencorporaTag('NOUN,inan,femn sing,loct'), normal_form='сталь', score=0.002739, methods_stack=((DictionaryAnalyzer(), 'стали', 13, 5),)),
#  Parse(word='стали', tag=OpencorporaTag('NOUN,inan,femn plur,accs'), normal_form='сталь', score=0.002739, methods_stack=((DictionaryAnalyzer(), 'стали', 13, 9),))]

# %%
morph.parse(word)[0].normal_form
# Out:
# 'корова'

# %% [markdown]
# 1. Создадим пустой словарь, куда записываем слова и частотность
# 2. Открываем файл в режиме чтения
# 3. Считываем файл построчно
# 4. Делаем всю строку в одном регистре
# 5. Удаляем пунктуацию
# 6. Приведение слова к начальной форме
# 6. Удаляем стоп-слова (из лематизированного)
# 8. Записываем слово и его частоту в словарь

# %%
"это" in stops
# Out:
# False

# %%
import re
from tqdm import tqdm
d = {}
with open('oblomov.txt', mode = 'r', encoding = 'utf-8') as infile:
    for l in tqdm(infile):
        l = l.lower()
        l = re.sub(punct_re, '', l)
        l = [morph.parse(word)[0].normal_form for word in l.split()]
        l = [word for word in l if word not in stops]
        for i in l:
            if i in d:
                d[i]+=1
            else:
                d[i]=1
# print(d)
# Out:
# 303it [00:00, 1111.87it/s]

# %% [markdown]
# 8. Отсортируем словарь по значениям по возрастанию

# %%
len(d)
# Out:
# 1076

# %%
sorted_tuple = sorted(d.items(), key = lambda x: x[1], reverse = True)
sorted_tuple
# Out:
# [('—', 208),
#  ('захар', 51),
#  ('обломов', 34),
#  ('это', 34),
#  ('всё', 32),
#  ('илья', 25),
#  ('ильич', 25),
#  ('сказать', 24),
#  ('свой', 20),
#  ('ещё', 20),
#  ('говорить', 19),
#  ('который', 16),
#  ('дом', 15),
#  ('лицо', 15),
#  ('лежать', 14),
#  ('мочь', 12),
#  ('письмо', 12),
#  ('барин', 12),
#  ('видеть', 10),
#  ('весь', 9),
#  ('встать', 9),
#  ('знать', 9),
#  ('стать', 8),
#  ('комната', 8),
#  ('кабинет', 8),
#  ('дело', 8),
#  ('староста', 8),
#  ('вон', 8),
#  ('квартира', 7),
#  ('человек', 7),
#  ('всякий', 7),
#  ('рука', 7),
#  ('убрать', 7),
#  ('пыль', 7),
#  ('думать', 7),
#  ('бог', 7),
#  ('уйти', 7),
#  ('постель', 6),
#  ('глаз', 6),
#  ('день', 6),
#  ('стоять', 6),
#  ('деревня', 6),
#  ('сторона', 6),
#  ('спросить', 6),
#  ('год', 5),
#  ('тело', 5),
#  ('казаться', 5),
#  ('немой', 5),
#  ('халат', 5),
#  ('широкий', 5),
#  ('нога', 5),
#  ('диван', 5),
#  ('картина', 5),
#  ('убирать', 5),
#  ('слуга', 5),
#  ('стена', 5),
#  ('стол', 5),
#  ('подумать', 5),
#  ('давно', 5),
#  ('чай', 5),
#  ('сделать', 5),
#  ('серый', 5),
#  ('сюртук', 5),
#  ('старый', 5),
#  ('платок', 5),
#  ('неделя', 5),
#  ('клоп', 5),
#  ('набраться', 5),
#  ('готовый', 5),
#  ('целый', 4),
#  ('взгляд', 4),
#  ('минута', 4),
#  ('душа', 4),
#  ('каждый', 4),
#  ('движение', 4),
#  ('мягкий', 4),
#  ('забота', 4),
#  ('покойный', 4),
#  ('хотя', 4),
#  ('глядеть', 4),
#  ('паутина', 4),
#  ('тарелка', 4),
#  ('валяться', 4),
#  ('жить', 4),
#  ('книга', 4),
#  ('неприятный', 4),
#  ('писать', 4),
#  ('план', 4),
#  ('умыться', 4),
#  ('начать', 4),
#  ('бакенбарда', 4),
#  ('ворчать', 4),
#  ('отвечать', 4),
#  ('пойти', 4),
#  ('дверь', 4),
#  ('посмотреть', 4),
#  ('ах', 4),
#  ('угол', 4),
#  ('выдумать', 4),
#  ('хороший', 4),
#  ('завтра', 4),
#  ('счёты', 4),
#  ('деньга', 4),
#  ('род', 3),
#  ('птица', 3),
#  ('складка', 3),
#  ('лоб', 3),
#  ('долго', 3),
#  ('вообще', 3),
#  ('плечо', 3),
#  ('идти', 3),
#  ('ходить', 3),
#  ('жилет', 3),
#  ('пол', 3),
#  ('необходимость', 3),
#  ('хотеть', 3),
#  ('первый', 3),
#  ('красный', 3),
#  ('дерево', 3),
#  ('несколько', 3),
#  ('стул', 3),
#  ('точно', 3),
#  ('хозяин', 3),
#  ('спрашивать', 3),
#  ('предмет', 3),
#  ('скорее', 3),
#  ('память', 3),
#  ('очень', 3),
#  ('час', 3),
#  ('досада', 3),
#  ('получить', 3),
#  ('третий', 3),
#  ('разный', 3),
#  ('новый', 3),
#  ('ничто', 3),
#  ('пора', 3),
#  ('послышаться', 3),
#  ('напоминать', 3),
#  ('старинный', 3),
#  ('отчий', 3),
#  ('звать', 3),
#  ('поди', 3),
#  ('ломать', 3),
#  ('нужный', 3),
#  ('найти', 3),
#  ('большой', 3),
#  ('прийти', 3),
#  ('заметить', 3),
#  ('везде', 3),
#  ('коли', 3),
#  ('жизнь', 3),
#  ('взять', 3),
#  ('мышь', 3),
#  ('сор', 3),
#  ('возразить', 3),
#  ('сын', 3),
#  ('давать', 3),
#  ('приставать', 3),
#  ('больший', 2),
#  ('утром', 2),
#  ('приятный', 2),
#  ('определённый', 2),
#  ('идея', 2),
#  ('черта', 2),
#  ('мысль', 2),
#  ('свет', 2),
#  ('беспечность', 2),
#  ('переходить', 2),
#  ('выражение', 2),
#  ('усталость', 2),
#  ('скука', 2),
#  ('мягкость', 2),
#  ('господствующий', 2),
#  ('улыбка', 2),
#  ('голова', 2),
#  ('взглянуть', 2),
#  ('должный', 2),
#  ('цвет', 2),
#  ('както', 2),
#  ('слишком', 2),
#  ('изнеженный', 2),
#  ('являться', 2),
#  ('редко', 2),
#  ('тревога', 2),
#  ('редкий', 2),
#  ('намерение', 2),
#  ('дремота', 2),
#  ('костюм', 2),
#  ('материя', 2),
#  ('восточный', 2),
#  ('намёк', 2),
#  ('весьма', 2),
#  ('место', 2),
#  ('естественный', 2),
#  ('достоинство', 2),
#  ('чувствовать', 2),
#  ('любить', 2),
#  ('туфля', 2),
#  ('непременно', 2),
#  ('служить', 2),
#  ('бюро', 2),
#  ('шёлковый', 2),
#  ('красивый', 2),
#  ('ковёр', 2),
#  ('мелочь', 2),
#  ('вкус', 2),
#  ('прочесть', 2),
#  ('лишь', 2),
#  ('хлопотать', 2),
#  ('этажерка', 2),
#  ('носить', 2),
#  ('смотреть', 2),
#  ('холодное', 2),
#  ('воззрение', 2),
#  ('вид', 2),
#  ('какихнибудь', 2),
#  ('пятно', 2),
#  ('забытый', 2),
#  ('полотенце', 2),
#  ('вчерашний', 2),
#  ('б', 2),
#  ('дветереть', 2),
#  ('развернуть', 2),
#  ('газета', 2),
#  ('чернильница', 2),
#  ('перо', 2),
#  ('видно', 2),
#  ('бросить', 2),
#  ('проснуться', 2),
#  ('обыкновение', 2),
#  ('рано', 2),
#  ('сильно', 2),
#  ('озаботить', 2),
#  ('тоска', 2),
#  ('ум', 2),
#  ('п', 2),
#  ('мера', 2),
#  ('тотчас', 2),
#  ('полчаса', 2),
#  ('мешать', 2),
#  ('лёжа', 2),
#  ('пробить', 2),
#  ('вслух', 2),
#  ('дать', 2),
#  ('воля', 2),
#  ('сначала', 2),
#  ('ворчание', 2),
#  ('собака', 2),
#  ('спрыгнуть', 2),
#  ('лежанка', 2),
#  ('время', 2),
#  ('погрузить', 2),
#  ('войти', 2),
#  ('торчать', 2),
#  ('клочок', 2),
#  ('стараться', 2),
#  ('образ', 2),
#  ('платье', 2),
#  ('слабый', 2),
#  ('воспоминание', 2),
#  ('ливрея', 2),
#  ('господин', 2),
#  ('гость', 2),
#  ('единственный', 2),
#  ('старик', 2),
#  ('барский', 2),
#  ('быт', 2),
#  ('остаться', 2),
#  ('предание', 2),
#  ('каприз', 2),
#  ('право', 2),
#  ('незаметно', 2),
#  ('друг', 2),
#  ('дорожить', 2),
#  ('задумчивость', 2),
#  ('прыжок', 2),
#  ('сильный', 2),
#  ('погрузиться', 2),
#  ('немного', 2),
#  ('захрипеть', 2),
#  ('голос', 2),
#  ('слово', 2),
#  ('никакой', 2),
#  ('положить', 2),
#  ('бумага', 2),
#  ('сей', 2),
#  ('починить', 2),
#  ('изломаться', 2),
#  ('доказывать', 2),
#  ('неудовольствие', 2),
#  ('удивление', 2),
#  ('упрёк', 2),
#  ('виноватый', 2),
#  ('делать', 2),
#  ('указать', 2),
#  ('указывать', 2),
#  ('хлеб', 2),
#  ('анисья', 2),
#  ('шкаф', 2),
#  ('сидеть', 2),
#  ('поглядеть', 2),
#  ('вздохнуть', 2),
#  ('равнодушно', 2),
#  ('отозваться', 2),
#  ('нечистота', 2),
#  ('перебить', 2),
#  ('бывать', 2),
#  ('чисто', 2),
#  ('отец', 2),
#  ('корка', 2),
#  ('баба', 2),
#  ('ступать', 2),
#  ('тронуть', 2),
#  ('какнибыть', 2),
#  ('ужас', 2),
#  ('передний', 2),
#  ('вставать', 2),
#  ('чрез', 2),
#  ('управлять', 2),
#  ('съехать', 2),
#  ('распорядиться', 2),
#  ('переезжать', 2),
#  ('бок', 2),
#  ('гороховый', 1),
#  ('улица', 1),
#  ('народонаселение', 1),
#  ('уездный', 1),
#  ('город', 1),
#  ('тридцать', 1),
#  ('двухтреха', 1),
#  ('среднее', 1),
#  ('рост', 1),
#  ('наружность', 1),
#  ('тёмно-серый', 1),
#  ('отсутствие', 1),
#  ('сосредоточенность', 1),
#  ('гулять', 1),
#  ('вольный', 1),
#  ('порхать', 1),
#  ('садиться', 1),
#  ('полуотворить', 1),
#  ('губа', 1),
#  ('прятаться', 1),
#  ('пропадать', 1),
#  ('теплиться', 1),
#  ('ровный', 1),
#  ('поза', 1),
#  ('шлафрок', 1),
#  ('помрачаться', 1),
#  ('согнать', 1),
#  ('основный', 1),
#  ('открыто', 1),
#  ('ясно', 1),
#  ('светиться', 1),
#  ('поверхностно', 1),
#  ('наблюдательный', 1),
#  ('холодный', 1),
#  ('мимоходом', 1),
#  ('«добряк', 1),
#  ('простота»', 1),
#  ('глубокий', 1),
#  ('симпатичный', 1),
#  ('вглядываться', 1),
#  ('отойти', 1),
#  ('раздумье', 1),
#  ('румяный', 1),
#  ('смуглый', 1),
#  ('положительно', 1),
#  ('бледный', 1),
#  ('безразличный', 1),
#  ('обрюзгнуть', 1),
#  ('недостаток', 1),
#  ('воздух', 1),
#  ('судить', 1),
#  ('матовый', 1),
#  ('чересчур', 1),
#  ('белый', 1),
#  ('шея', 1),
#  ('маленький', 1),
#  ('пухлый', 1),
#  ('мужчина', 1),
#  ('встревожить', 1),
#  ('сдерживаться', 1),
#  ('также', 1),
#  ('лишённый', 1),
#  ('грация', 1),
#  ('лень', 1),
#  ('набегать', 1),
#  ('туча', 1),
#  ('туманиться', 1),
#  ('начинаться', 1),
#  ('игра', 1),
#  ('сомнение', 1),
#  ('печаль', 1),
#  ('испуг', 1),
#  ('застывать', 1),
#  ('форма', 1),
#  ('превращаться', 1),
#  ('разрешаться', 1),
#  ('вздох', 1),
#  ('замирать', 1),
#  ('апатия', 1),
#  ('домашний', 1),
#  ('персидский', 1),
#  ('настоящий', 1),
#  ('малый', 1),
#  ('европа', 1),
#  ('кисть', 1),
#  ('бархат', 1),
#  ('талия', 1),
#  ('поместительный', 1),
#  ('дважды', 1),
#  ('завернуться', 1),
#  ('рукав', 1),
#  ('неизменный', 1),
#  ('азиатский', 1),
#  ('мода', 1),
#  ('палец', 1),
#  ('утратить', 1),
#  ('первоначальный', 1),
#  ('свежесть', 1),
#  ('заменить', 1),
#  ('первобытный', 1),
#  ('лоск', 1),
#  ('благоприобретённый', 1),
#  ('сохранять', 1),
#  ('яркость', 1),
#  ('краска', 1),
#  ('прочность', 1),
#  ('ткань', 1),
#  ('иметь', 1),
#  ('тьма', 1),
#  ('неоценённый', 1),
#  ('гибкий', 1),
#  ('послушный', 1),
#  ('раб', 1),
#  ('покоряться', 1),
#  ('самомалейший', 1),
#  ('галстук', 1),
#  ('простор', 1),
#  ('приволье', 1),
#  ('длинный', 1),
#  ('опускать', 1),
#  ('попадать', 1),
#  ('сразу', 1),
#  ('лежание', 1),
#  ('больной', 1),
#  ('спать', 1),
#  ('случайность', 1),
#  ('устать', 1),
#  ('наслаждение', 1),
#  ('лентяй', 1),
#  ('нормальный', 1),
#  ('состояние', 1),
#  ('постоянно', 1),
#  ('наслать', 1),
#  ('спальня', 1),
#  ('приёмный', 1),
#  ('туда', 1),
#  ('заглядывать', 1),
#  ('мел', 1),
#  ('делаться', 1),
#  ('мебель', 1),
#  ('закрытый', 1),
#  ('чехол', 1),
#  ('штора', 1),
#  ('спустить', 1),
#  ('прекрасно', 1),
#  ('обить', 1),
#  ('ширма', 1),
#  ('вышитый', 1),
#  ('небывалый', 1),
#  ('природа', 1),
#  ('плод', 1),
#  ('занавес', 1),
#  ('бронза', 1),
#  ('фарфор', 1),
#  ('множество', 1),
#  ('опытный', 1),
#  ('чистый', 1),
#  ('беглый', 1),
#  ('желание', 1),
#  ('коекак', 1),
#  ('соблюсти', 1),
#  ('decorum1', 1),
#  ('неизбежный', 1),
#  ('приличие', 1),
#  ('отделаться', 1),
#  ('утончить', 1),
#  ('удовольствоваться', 1),
#  ('тяжёлый', 1),
#  ('неграциозный', 1),
#  ('шаткий', 1),
#  ('задок', 1),
#  ('осесться', 1),
#  ('вниз', 1),
#  ('наклеить', 1),
#  ('отстать', 1),
#  ('характер', 1),
#  ('ваза', 1),
#  ('однако', 1),
#  ('убранство', 1),
#  ('холодно', 1),
#  ('рассеянно', 1),
#  ('«кто', 1),
#  ('сюда', 1),
#  ('натащить', 1),
#  ('наставить', 1),
#  ('это»', 1),
#  ('собственность', 1),
#  ('осмотреть', 1),
#  ('внимательный', 1),
#  ('поражать', 1),
#  ('запущенность', 1),
#  ('небрежность', 1),
#  ('около', 1),
#  ('лепиться', 1),
#  ('фестон', 1),
#  ('напитать', 1),
#  ('зеркало', 1),
#  ('вместо', 1),
#  ('отражать', 1),
#  ('скрижаль', 1),
#  ('записывание', 1),
#  ('заметка', 1),
#  ('утро', 1),
#  ('ужин', 1),
#  ('солонка', 1),
#  ('обглодать', 1),
#  ('косточка', 1),
#  ('хлебный', 1),
#  ('крошка', 1),
#  ('прислонить', 1),
#  ('выкурить', 1),
#  ('трубка', 1),
#  ('никто', 1),
#  ('запылиться', 1),
#  ('полинялый', 1),
#  ('лишить', 1),
#  ('живой', 1),
#  ('след', 1),
#  ('человеческий', 1),
#  ('присутствие', 1),
#  ('правда', 1),
#  ('страница', 1),
#  ('покрыться', 1),
#  ('пожелтеть', 1),
#  ('нумереть', 1),
#  ('прошлогодний', 1),
#  ('обмакнуть', 1),
#  ('вырваться', 1),
#  ('жужжание', 1),
#  ('испуганный', 1),
#  ('муха', 1),
#  ('против', 1),
#  ('восемь', 1),
#  ('чемтый', 1),
#  ('попеременно', 1),
#  ('выступать', 1),
#  ('страх', 1),
#  ('одолевать', 1),
#  ('внутренний', 1),
#  ('борьба', 1),
#  ('помощь', 1),
#  ('накануне', 1),
#  ('содержание', 1),
#  ('известно', 1),
#  ('неприятность', 1),
#  ('неурожай', 1),
#  ('недоимка', 1),
#  ('уменьшение', 1),
#  ('доход', 1),
#  ('прошлый', 1),
#  ('последний', 1),
#  ('подействовать', 1),
#  ('сюрприз', 1),
#  ('легко', 1),
#  ('предстоять', 1),
#  ('средство', 1),
#  ('принятие', 1),
#  ('отдать', 1),
#  ('справедливость', 1),
#  ('заботливость', 1),
#  ('назад', 1),
#  ('создавать', 1),
#  ('перемена', 1),
#  ('улучшение', 1),
#  ('порядок', 1),
#  ('управление', 1),
#  ('имение', 1),
#  ('предполагаться', 1),
#  ('ввести', 1),
#  ('экономический', 1),
#  ('полицейский', 1),
#  ('далеко', 1),
#  ('обдуманный', 1),
#  ('ежегодно', 1),
#  ('повторяться', 1),
#  ('побуждать', 1),
#  ('деятельность', 1),
#  ('следовательно', 1),
#  ('нарушать', 1),
#  ('покой', 1),
#  ('сознавать', 1),
#  ('окончание', 1),
#  ('предпринять', 1),
#  ('чтонибыть', 1),
#  ('решительный', 1),
#  ('вознамериться', 1),
#  ('напиться', 1),
#  ('хорошенько', 1),
#  ('коечто', 1),
#  ('сообразить', 1),
#  ('записать', 1),
#  ('заняться', 1),
#  ('следовать', 1),
#  ('мучиться', 1),
#  ('рассудить', 1),
#  ('успеть', 1),
#  ('пить', 1),
#  ('приподняться', 1),
#  ('ложа', 1),
#  ('поглядывать', 1),
#  ('спускать', 1),
#  ('подобрать', 1),
#  ('половина', 1),
#  ('десятый', 1),
#  ('встрепенуться', 1),
#  ('совесть', 1),
#  ('и…', 1),
#  ('закричать', 1),
#  ('отделяться', 1),
#  ('небольшой', 1),
#  ('коридор', 1),
#  ('цепной', 1),
#  ('стук', 1),
#  ('откудато', 1),
#  ('обыкновенно', 1),
#  ('проводить', 1),
#  ('сидя', 1),
#  ('пожилой', 1),
#  ('прореха', 1),
#  ('мышка', 1),
#  ('откуда', 1),
#  ('рубашка', 1),
#  ('медный', 1),
#  ('пуговица', 1),
#  ('голый', 1),
#  ('колено', 1),
#  ('череп', 1),
#  ('необъятно', 1),
#  ('густой', 1),
#  ('русый', 1),
#  ('проседь', 1),
#  ('борода', 1),
#  ('изменить', 1),
#  ('данный', 1),
#  ('шиться', 1),
#  ('вывезти', 1),
#  ('образец', 1),
#  ('нравиться', 1),
#  ('полуформенный', 1),
#  ('одежда', 1),
#  ('некогда', 1),
#  ('провожать', 1),
#  ('церковь', 1),
#  ('представительница', 1),
#  ('глушь', 1),
#  ('умереть', 1),
#  ('фамильный', 1),
#  ('портрет', 1),
#  ('гденибыть', 1),
#  ('чердак', 1),
#  ('важность', 1),
#  ('фамилия', 1),
#  ('глохнуть', 1),
#  ('немногий', 1),
#  ('поэтому', 1),
#  ('дорога', 1),
#  ('коекакий', 1),
#  ('признак', 1),
#  ('сохраниться', 1),
#  ('манер', 1),
#  ('родитель', 1),
#  ('уважать', 1),
#  ('внутренне', 1),
#  ('проявление', 1),
#  ('господский', 1),
#  ('отживший', 1),
#  ('величие', 1),
#  ('воскрешать', 1),
#  ('молодость', 1),
#  ('покинуть', 1),
#  ('хроника', 1),
#  ('вести', 1),
#  ('нянька', 1),
#  ('мамка', 1),
#  ('передаваемый', 1),
#  ('родиться', 1),
#  ('когдато', 1),
#  ('богатый', 1),
#  ('знаменитый', 1),
#  ('беднеть', 1),
#  ('мельчать', 1),
#  ('потеряться', 1),
#  ('дворянский', 1),
#  ('поседеть', 1),
#  ('хранить', 1),
#  ('передавать', 1),
#  ('верный', 1),
#  ('минувший', 1),
#  ('святыня', 1),
#  ('детство', 1),
#  ('аристократический', 1),
#  ('украшение', 1),
#  ('замечать', 1),
#  ('молча', 1),
#  ('кашлянуть', 1),
#  ('помнить', 1),
#  ('потягиваться', 1),
#  ('пока', 1),
#  ('вспомнить', 1),
#  ('продолжать', 1),
#  ('проклятый', 1),
#  ('пройти', 1),
#  ('четверть', 1),
#  ('полно', 1),
#  ('встать…', 1),
#  ('дайка', 1),
#  ('внимание', 1),
#  ('неблагосклонный', 1),
#  ('посматривать', 1),
#  ('стоятьто', 1),
#  ('даром', 1),
#  ('неимение', 1),
#  ('потерять', 1),
#  ('охота', 1),
#  ('ездить', 1),
#  ('дунуть', 1),
#  ('ветер', 1),
#  ('горло', 1),
#  ('вполуоборот', 1),
#  ('среди', 1),
#  ('отсохнуть', 1),
#  ('постоять', 1),
#  ('подождать', 1),
#  ('залежаться', 1),
#  ('сыскать', 1),
#  ('вчера', 1),
#  ('видать', 1),
#  ('почтальон', 1),
#  ('принять', 1),
#  ('грязный', 1),
#  ('почему', 1),
#  ('похлопывать', 1),
#  ('вещь', 1),
#  ('корзина', 1),
#  ('завалиться', 1),
#  ('спинкато', 1),
#  ('призвать', 1),
#  ('столяр', 1),
#  ('изломать', 1),
#  ('век', 1),
#  ('когданибудь', 1),
#  ('счесть', 1),
#  ('противный', 1),
#  ('какиеть', 1),
#  ('нетерпение', 1),
#  ('упереться', 1),
#  ('прыгнуть', 1),
#  ('торопливый', 1),
#  ('крик', 1),
#  ('«захар', 1),
#  ('захар»', 1),
#  ('господь', 1),
#  ('отправляться', 1),
#  ('мучение', 1),
#  ('смерть', 1),
#  ('придерживаться', 1),
#  ('знак', 1),
#  ('неблаговоление', 1),
#  ('приходиться', 1),
#  ('вполглаза', 1),
#  ('видный', 1),
#  ('необъятный', 1),
#  ('ждать', 1),
#  ('вылететь', 1),
#  ('носовой', 1),
#  ('скорый', 1),
#  ('догадаться', 1),
#  ('строго', 1),
#  ('обнаружить', 1),
#  ('особенный', 1),
#  ('приказание', 1),
#  ('находить', 1),
#  ('вероятно', 1),
#  ('обходить', 1),
#  ('вокруг', 1),
#  ('ощупывать', 1),
#  ('терять', 1),
#  ('отворять', 1),
#  ('гостиный', 1),
#  ('искать', 1),
#  ('нету', 1),
#  ('разводить', 1),
#  ('озираться', 1),
#  ('сердито', 1),
#  ('конец', 1),
#  ('дожидаться', 1),
#  ('ответ', 1),
#  ('неловко', 1),
#  ('собственный', 1),
#  ('промах', 1),
#  ('быстро', 1),
#  ('повод', 1),
#  ('чистота', 1),
#  ('пылить', 1),
#  ('грязитый', 1),
#  ('поглядик', 1),
#  ('углахтый', 1),
#  ('делаю…', 1),
#  ('заговорить', 1),
#  ('обиженный', 1),
#  ('жалеть', 1),
#  ('пыльто', 1),
#  ('стирать', 1),
#  ('метуть', 1),
#  ('день…', 1),
#  ('середина', 1),
#  ('обедать', 1),
#  ('подмести', 1),
#  ('прибрать', 1),
#  ('словно', 1),
#  ('свадьбе…', 1),
#  ('прервать', 1),
#  ('потолок', 1),
#  ('ломоть', 1),
#  ('пожалуй', 1),
#  ('снисходительно', 1),
#  ('святой', 1),
#  ('чистить', 1),
#  ('снимаю…', 1),
#  ('обмести', 1),
#  ('рождество', 1),
#  ('перебрать', 1),
#  ('театр', 1),
#  ('бы…', 1),
#  ('уборка', 1),
#  ('ночью', 1),
#  ('покачать', 1),
#  ('окно', 1),
#  ('«ну', 1),
#  ('брат', 1),
#  ('нежели', 1),
#  ('сам»', 1),
#  ('«врать', 1),
#  ('мастер', 1),
#  ('мудрёный', 1),
#  ('жалкий', 1),
#  ('нет»', 1),
#  ('понимать', 1),
#  ('заводиться', 1),
#  ('моль', 1),
#  ('блоха', 1),
#  ('гадость', 1),
#  ('усмехнуться', 1),
#  ('усмешка', 1),
#  ('охватить', 1),
#  ('бровь', 1),
#  ('раздвинуться', 1),
#  ('расплыться', 1),
#  ('наивный', 1),
#  ('врать', 1),
#  ('бегать', 1),
#  ('ночь', 1),
#  ('слышать', 1),
#  ('тварь', 1),
#  ('кошка', 1),
#  ('молить', 1),
#  ('выразиться', 1),
#  ('недоверчивость', 1),
#  ('уверенность', 1),
#  ('упрямо', 1),
#  ('усмотреть', 1),
#  ('щёлка', 1),
#  ('влезть', 1),
#  ('«да', 1),
#  ('спаньё', 1),
#  ('клопа»', 1),
#  ('мести', 1),
#  ('выбирать', 1),
#  ('учить', 1),
#  ('твердить', 1),
#  ('вымести', 1),
#  ('перебирать', 1),
#  ('послать', 1),
#  ('напротив', 1),
#  ('настройщик', 1),
#  ('любо', 1),
#  ('девка…', 1),
#  ('немец', 1),
#  ('поглядитёкий', 1),
#  ('семья', 1),
#  ('кость', 1),
#  ('глодать', 1),
#  ('жена', 1),
#  ('дочь', 1),
#  ('платьишко', 1),
#  ('коротенький', 1),
#  ('поджимать', 1),
#  ('гусыни…', 1),
#  ('куча', 1),
#  ('старое', 1),
#  ('износить', 1),
#  ('зиму…', 1),
#  ('зря', 1),
#  ('наделать', 1),
#  ('сухарик', 1),
#  ('пиво', 1),
#  ('выпить', 1),
#  ('сквозь', 1),
#  ('зуб', 1),
#  ('плюнуть', 1),
#  ('рассуждать', 1),
#  ('скаредный', 1),
#  ('житие', 1),
#  ('нечего', 1),
#  ('разговаривать', 1),
#  ('иной', 1),
#  ('подик', 1),
#  ('настаивать', 1),
#  ('сегодня', 1),
#  ('управиться', 1),
#  ('вдвоемтый', 1),
#  ('нанять', 1),
#  ('перемыть', 1),
#  ('э', 1),
#  ('затея', 1),
#  ('рад', 1),
#  ('вызвать', 1),
#  ('разговор', 1),
#  ('забывать', 1),
#  ('деликатный', 1),
#  ('обобраться', 1),
#  ('хлопоты', 1),
#  ('хотеться', 1),
#  ('желать', 1),
#  ('сделаться', 1),
#  ('заводить', 1),
#  ('тяжба', 1),
#  ('начинать', 1),
#  ('требовать', 1),
#  ('сметание', 1),
#  ('мытьё', 1),
#  ('случай', 1),
#  ('громадный', 1),
#  ('возня', 1),
#  ('приводить', 1),
#  ('размышление', 1),
#  ('одиннадцать', 1),
#  ('скоро', 1),
#  ('известный', 1),
#  ('вслед', 1),
#  ('заниматься', 1),
#  ('сесть', 1),
#  ('воротиться', 1),
#  ('исписать', 1),
#  ('замаслить', 1),
#  ('тетрадка', 1),
#  ('кстати', 1),
#  ('изволить', 1),
#  ('поверить', 1),
#  ('заплатить', 1),
#  ('мясник', 1),
#  ('зеленщик', 1),
#  ('прачка', 1),
#  ('хлебник', 1),
#  ('просить', 1),
#  ('понемногу', 1),
#  ('подавать', 1),
#  ('прогонять', 1),
#  ('завтра…', 1),
#  ('долг', 1),
#  ('нынче', 1),
#  ('число', 1),
#  ('стоить', 1),
#  ('умытьсять', 1),
#  ('теперь…', 1),
#  ('кряхтеть', 1),
#  ('приподниматься', 1),
#  ('забыть', 1),
#  ('давеча', 1),
#  ('почивать', 1),
#  ('дворник', 1),
#  ('прислать', 1),
#  ('съехать…', 1),
#  ('разумеется', 1),
#  ('месяц', 1),
#  ('обещать', 1),
#  ('съезжать', 1),
#  ...]

# %%
list(d.items())[0][1]
# Out:
# 1

# %% [markdown]
# 9. Создадим файл, куда запишем таблицу-частотности в следующем форморате:
#
# ('слово', частота)
#
# Каждое на новой строке

# %%
with open('frq_oblomov.txt', mode = 'w', encoding = 'utf-8') as outfile:
    print(*sorted_tuple, file = outfile, sep = '\n')

# %% [markdown]
# ### Задание 3

# %% [markdown]
# Вам предоставили список людей, которые подали заявку на получение Пушкинской карты (**task2.csv**). Условием получения Пушкинской карты является возраст от 14 до 22 лет (2001-2007), включительно, и наличие гражданства РФ. Напишите программу, которая записывает в новый файл все строки, которые соответствуют людям из определенного города которые могут получить Пушкинскую карту.
#
# Итоговый файл должен называться: **pk_list_ГОРОД.csv**

# %%
city = input()
lst = []

with open('task2.csv', mode = 'r', encoding = 'utf-8') as infile:
    for l in infile:
        s = l.strip().split(',')
        if s[-1] == city and s[-2] == 'RU' and int(s[1][-4:]) in range(2001, 2008):
            lst.append(l.strip())

with open(f'pk_list_{city}.csv', mode = 'w', encoding = 'utf-8') as outfile:
    print(*lst, file = outfile, sep = '\n')
# Out:
# Москва

# %% [markdown]
# Посчитайте сколько людей из каждого города могут получить Пушкинскую карту

# %% [markdown]
# ### Задание 4

# %% [markdown]
# Нужно сделать подборку лучших упражнений (рейтинг не меньше 8.5) для спины (в описании есть слово "спины")из тех которые доступны в приложении для определенного уровня сложности и оборудования. Информация о всех упражнениях хранится в файле в формате **task3.tsv**.
#
#
# На каждой строке записана следующая информация об упражнении: Название, Тип, Часть тела, Оборудование, Уровень сложности, Рейтинг.
#
# *Например, "Barbell roll-out,Сила,Средняя часть спины,Штанга,Эксперт,9.8"*

# %% [markdown]
# Посчитайте средний рейтинг всех упражнений из приложения

# %% [markdown]
# ## Try except

# %% [markdown]
# Почти наверняка вы уже делали что-то, что приводило к сообщению об ошибке. Сегодня мы научимся их обрабатывать и писать собственные исключения - наши инструкции для Python, чтобы код не ломался, как только что-то пойдет не так.
#
# Например, мы хотим открывать файл по запросу от пользователя, но хотим обработать случай, когда пользователь введет неправильное название.

# %%
fname = input('Введите название файла: ')
fhand = open(fname) # введем название несуществующего файла
# Out:
# Введите название файла: bfhdsjkbjdksajkba
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[68], line 2
#       1 fname = input('Введите название файла: ')
# ----> 2 fhand = open(fname)
#
# File /opt/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'bfhdsjkbjdksajkba'

# %% [markdown]
# Напишем блок `try`/`except`. Try будет исполняться до тех пор, пока что-то не сломается. Как только возникнет ошибка, ваша программа перейдет в часть `except` и выполнит действие, описанное в ней. Сообщения об ошибке выведено не будет.

# %%
name = input()

try:
    with open(name) as infile:
        for l in infile:
            print(l)
except:
    print('Файл не найден')
# Out:
# xcvbnm
# Файл не найден

# %%
# Out:
# 18446744073709551616

# %%
import numpy as np

# %%
integers = np.random.randint(1, 100000, size = 1000)

# %%
import matplotlib.pyplot as plt

# %%
_ = plt.hist(integers, bins = 100)

# %%
np.mean(integers)
# Out:
# 49914.565

# %%
from scipy.stats.mstats import gmean, hmean

gmean(integers)
# Out:
# 36788.59506126397

# %%
hmean(integers)
# Out:
# 13476.230481004906

# %% [markdown]
# Mожно не ломать код из-за ошибки, а просто продолжать его выполнять:
# ``` python
# try:
#     <инструкция>
# except:
#     pass

# %%
with open('tryexpect.txt') as infile:
        for l in infile:
            print(l)
# Out:
# 1
#
# one
#
# two
#
# 3
#
# 4
#
# 5
#
# six
#
# seven
#
# eight

# %%
s = 0
with open('tryexpect.txt') as infile:
        for l in infile:
            s+=int(l.strip())
print(s)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/qg/08y10w1n1mb78ynxwmg8fmp00000gn/T/ipykernel_24212/1217219568.py in <module>
#       2 with open('tryexpect.txt') as infile:
#       3         for l in infile:
# ----> 4             s+=int(l.strip())
#       5 print(s)
#
# ValueError: invalid literal for int() with base 10: 'one'

# %%
s = 0
with open('tryexpect.txt') as infile:
        for l in infile:
            try:
                s+=int(l.strip())
            except:
                pass
print(s)
# Out:
# 13

# %% [markdown]
# Но что делать, если мы хотим пропускать только определенный вид ошибок, но видеть сообщения об остальных? Try/except хороший инструмент для отладки кода. Давайте посмотрим, как называется ошибка при попытке вызова неопределенной переменной.

# %%
print(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/qg/08y10w1n1mb78ynxwmg8fmp00000gn/T/ipykernel_24212/1056546137.py in <module>
# ----> 1 print(y)
#
# NameError: name 'y' is not defined

# %% [markdown]
# Чтобы прописать инструкцию для конретного типа ошибок:
#
# ```python
# try:
#     <инструкция>
# except <тип ошибки>:
#     <инструкция>
# ```

# %%
try:
    print(y)
except NameError:
    print("Variable y is not defined")
except:
    print("Something else went wrong")

# %% [markdown]
# Иногда вам может понадобиться создавать свои исключения - персонализированные сообщения об ошибке, которые валидны только для вашей программы. Сделать это можно с помощью `raise Exception(<Ваше сообщение>)`

# %%
x = -1

if x < 0:
    raise Exception("Число не может быть отрицательным")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/qg/08y10w1n1mb78ynxwmg8fmp00000gn/T/ipykernel_24212/1586720503.py in <module>
#       2
#       3 if x < 0:
# ----> 4     raise "Число не может быть отрицательным"
#
# TypeError: exceptions must derive from BaseException

# %%
x = "hello"

if not type(x) is int:
    raise TypeError("Only integers are allowed")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/qg/08y10w1n1mb78ynxwmg8fmp00000gn/T/ipykernel_24212/1129330155.py in <module>
#       2
#       3 if not type(x) is int:
# ----> 4     raise TypeError("Only integers are allowed")
#
# TypeError: Only integers are allowed

# %% [markdown]
# ## Указание типов в Python

# %%
import typing #содержит описание всех типов данных

# %%
x:int =1

# %%
x = 'fhshl'

# %%
x
# Out:
# 'fhshl'

# %% [markdown]
# Если вы разметили все данные, то можно запустить линтер (специальный инструмент) по коду, который проверит, что тип данных соответствует указанаому, и не нужно будет выискивать, где вы допустили ошибку

# %% [markdown]
# Добавим к строке отступ:

# %%
def indent_right(s:str, amount:int) -> str:
    return " " * max(0, amount) + s

# %% [markdown]
# Описание с учетом None

# %%
from typing import Optional #для учета None

# %%
amount: int
amount = None #В переменную передан None, а должено быть целое число

# %%
price: Optianal[int]
price = None #Вот теперь мы учли случай, когда не только int, но и None
